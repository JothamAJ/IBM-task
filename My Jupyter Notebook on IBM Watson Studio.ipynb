# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __My name is Jotham Ajakaiye__
# _My desired occupation is data analyst_

# %% [markdown]
# _I am passionate about data science because I understand the importance of using data to help inform decisions. I believe that it is a very useful tool as it gives us many different insights_

# %% [markdown]
# ### Sell 5 is a code that is adding 10 to 10

# %%
10 + 10
# Out:
# 20

# %% [markdown]
# Football teams
# * Liverpool
# * Barcelona
# * Real Madrid
#
# 1. German teams
#     1. FC Bayern Munich
#     2. Borussia Dortmund
#     3. RB Leipzig
#
#
#
#
# 2. French teams
#     1. Paris Saint Germain FC
#     2. AS Monaco
#     3. OGC Nice
#
#
# ![Liverpool-emblem.png](attachment:Liverpool-emblem.png)
